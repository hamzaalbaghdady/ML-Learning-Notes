# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzaalbaghdady/ML-Learning-Notes/blob/main/PandasTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Get_Dataset

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Access culomns:

# %%
df.sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
df['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
df['sex'][5]
# Out:
# 'male'

# %% [markdown]
# # iLoc[]

# %%
df.iloc[5]
# Out:
# survived                0
# pclass                  3
# sex                  male
# age                   NaN
# sibsp                   0
# parch                   0
# fare               8.4583
# embarked                Q
# class               Third
# who                   man
# adult_male           True
# deck                  NaN
# embark_town    Queenstown
# alive                  no
# alone                True
# Name: 5, dtype: object

# %%
df.iloc[5:,2]
# Out:
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 886, dtype: object

# %%
df.iloc[100:110,[0,2,3,8]]
# Out:
#      survived     sex   age  class
# 100         0  female  28.0  Third
# 101         0    male   NaN  Third
# 102         0    male  21.0  First
# 103         0    male  33.0  Third
# 104         0    male  37.0  Third
# 105         0    male  28.0  Third
# 106         1  female  21.0  Third
# 107         1    male   NaN  Third
# 108         0    male  38.0  Third
# 109         1  female   NaN  Third
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['survived'].plot(kind='hist', bins=20, title='survived')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %% [markdown]
# # Manipulating the index

# %%
df.set_index("sex")
# Out:
#      survived  pclass   age  sibsp  parch     fare embarked   class    who  \
# sex
# 1           0       3  22.0      1      0   7.2500        S   Third    man
# 1           1       1  38.0      1      0  71.2833        C   First  woman
# 1           1       3  26.0      0      0   7.9250        S   Third  woman
# 1           1       1  35.0      1      0  53.1000        S   First  woman
# 1           0       3  35.0      0      0   8.0500        S   Third    man
# ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
# 1           0       2  27.0      0      0  13.0000        S  Second    man
# 1           1       1  19.0      0      0  30.0000        S   First  woman
# 1           0       3   NaN      1      2  23.4500        S   Third  woman
# 1           1       1  26.0      0      0  30.0000        C   First    man
# 1           0       3  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# sex
# ...

# %% [markdown]
# # Conditional selection

# %%
# df.sex=="male"
# df.loc[df.sex=="male"]
# df.loc[(df.sex=='male')& (df.age >20)]
# df.loc[(df.sex=='female') | (df['class']=='First')]
# df.loc[df.age.isin([20,30,40])]
df.loc[df.age.notnull()]
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# # Exercises:

# %%
# level 1
df.iloc[:5]
df.iloc[:10,:3]
df.iloc[-3:]
df.iloc[:,[3,6]]
df.iloc[10:15,2:5]
df.iloc[100,3]
# df.iloc[5++] # i have no clue

# level 2
df.loc[:5,['sex','age']] # there is no name culomn
df.loc[df.sex=="female"]
df.loc[df.age>50]
df.loc[df.fare>100,['sex','age','fare']] # there is no name culomn
df.loc[(df.embarked=="S")&(df.survived==1)]
df.loc[df.age.isnull()]
df.loc[(df.pclass==3)&(df.sex=="male")&(df.age<18)]

# level 3
data=df.loc[df.fare>50]
data.iloc[:5]

data=df.iloc[:10]
data.loc[:,['age','sex','fare']]

data=df.loc[df.survived==0]
data.iloc[-3:]

#Bonus

df.loc[df.age.isnull()] = df.age.median()
df['is_child']= df.age<18
df.loc[df.pclass==1,"fare"]=df.fare*1.1

# Challenge
data= df.sort_values('age', ascending=False)
data=data.loc[data.survived==1,['age','class']]
data.iloc[:5]

male=df.loc[(df.embarked=='C')&(df.sex=='male'),'fare'].mean()
female=df.loc[(df.embarked=='C')&(df.sex=='female'),'fare'].mean()

subdata=df.loc[(df.age>20)&(df.age<40),['sex','age','pclass','survived'] ]

averageFare=df.fare.mean()*2
df.loc[df.fare < averageFare]
# there is no name culomn in this data set
df.loc[df.embarked == 'C'].groupby('sex')['fare'].mean()
# Out:
# sex
# female    1411.600578
# male       992.925742
# Name: fare, dtype: float64

# %% [markdown]
# # Summary Functions and Maps

# %%
df.age.describe()
df.age.mean()
df.pclass.unique()
df.sex.value_counts()
df.age.map(lambda x: x-5)

def minus5(column):
  column-=5
  return column
df.age.apply(minus5)
# Out:
# 0      17.0
# 1      33.0
# 2      21.0
# 3      30.0
# 4      30.0
#        ...
# 886    22.0
# 887    14.0
# 888     NaN
# 889    21.0
# 890    27.0
# Name: age, Length: 891, dtype: float64

# %%
df.age -5
df.sex + " : " + df['class']
# Out:
# 0        male : Third
# 1      female : First
# 2      female : Third
# 3      female : First
# 4        male : Third
#             ...
# 886     male : Second
# 887    female : First
# 888    female : Third
# 889      male : First
# 890      male : Third
# Length: 891, dtype: object

# %%
df.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
df.fare.plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# # Grouping and Sorting

# %%
df.age.value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.groupby('age').age.count()
# Out:
# age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    2
# 70.50    1
# 71.00    2
# 74.00    1
# 80.00    1
# Name: age, Length: 88, dtype: int64

# %%
df.groupby(['age','sex']).age.count()
# Out:
# age    sex
# 0.42   male      1
# 0.67   male      1
# 0.75   female    2
# 0.83   male      2
# 0.92   male      1
#                 ..
# 70.00  male      2
# 70.50  male      1
# 71.00  male      2
# 74.00  male      1
# 80.00  male      1
# Name: age, Length: 145, dtype: int64

# %%
df.groupby('age').age.agg([len,min,max])
# Out:
# /tmp/ipython-input-2546169609.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('age').age.agg([len,min,max])
# /tmp/ipython-input-2546169609.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('age').age.agg([len,min,max])
#        len    min    max
# age
# 0.42     1   0.42   0.42
# 0.67     1   0.67   0.67
# 0.75     2   0.75   0.75
# 0.83     2   0.83   0.83
# 0.92     1   0.92   0.92
# ...    ...    ...    ...
# 70.00    2  70.00  70.00
# 70.50    1  70.50  70.50
# 71.00    2  71.00  71.00
# 74.00    1  74.00  74.00
# 80.00    1  80.00  80.00
#
# [88 rows x 3 columns]

# %%
df.groupby('sex').fare.mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
df.groupby(['sex','pclass']).fare.mean()
# Out:
# sex     pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: fare, dtype: float64

# %%
df.groupby('sex')['fare'].agg(['mean', 'std', 'min', 'max'])
# Out:
#              mean        std   min       max
# sex
# female  44.479818  57.997698  6.75  512.3292
# male    25.523893  43.138263  0.00  512.3292

# %% [markdown]
# ## Sorting

# %%
df.loc[df.age.notnull()].age.sort_values(ascending=False)
# Out:
# 630    80.00
# 851    74.00
# 493    71.00
# 96     71.00
# 116    70.50
#        ...
# 831     0.83
# 644     0.75
# 469     0.75
# 755     0.67
# 803     0.42
# Name: age, Length: 714, dtype: float64

# %%
df.sort_values(by=['age','fare'], ascending=False)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1  male  80.0      0      0  30.0000        S   First
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 493         0       1  male  71.0      0      0  49.5042        C   First
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 481         0       2  male   NaN      0      0   0.0000        S  Second
# 633         0       1  male   NaN      0      0   0.0000        S   First
# 674         0       2  male   NaN      0      0   0.0000        S  Second
# 732         0       2  male   NaN      0      0   0.0000        S  Second
# 815         0       1  male   NaN      0      0   0.0000        S   First
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sort_index()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Data Types and Missing Values

# %%
df.age.dtype
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df.age.fillna(90)
df.describe()
df.loc[df.age.isnull()]
df.embarked.replace('Q','New')
df.loc[df.embarked=='New']
df.head(15)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# # Renaming and Combining

# %%
df.rename(columns={'sex':'gender'})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-36748913.py in <cell line: 0>()
# ----> 1 canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
#       2 british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")
#
# ...
